# %%
#imported libraries
import pandas as pd
import numpy as np
import json
import csv

# %%
df = pd.read_csv("freecodecamp org id T.csv")
# output the dataframe
print(df)
# Out:
#                                                   Title  \
# 0            JavaScript Tutorial - Create a Card Game 🃏
# 1     Next.js React Framework Course – Build and Dep...
# 2     Swift Programming Tutorial – Full Course for B...
# 3     Learn Python GUI Development for Desktop – PyS...
# 4                     MATLAB Crash Course for Beginners
# ...                                                 ...
# 1378        Computer Basics 5: How To Measure Data Size
# 1379        Computer Basics 4: Decoding a Binary Number
# 1380            Computer Basics 3: Intro to Binary Code
# 1381          Computer Basics 2: More Computer Hardware
# 1382  Computer Basics 1: The 4 Basic Parts of a Comp...
#
#                                 Link           id
# 0     http://www.youtube.com/watch?v  Bj6lC93JMi0
# 1     http://www.youtube.com/watch?v  KjY94sAKLlw
# 2     http://www.youtube.com/watch?v  8Xg7E9shq0U
# 3     http://www.youtube.com/watch?v  Z1N9JzNax2k
# 4     http://www.youtube.com/watch?v  7f50sQYjNRA
# ...                              ...          ...
# 1378  http://www.youtube.com/watch?v  _uWzpyr_5qk
# 1379  http://www.youtube.com/watch?v  xXLj5MbrI44
# 1380  http://www.youtube.com/watch?v  veugT7A9psY
# 1381  http://www.youtube.com/watch?v  xj9mFD71Vfc
# 1382  http://www.youtube.com/watch?v  q7tlgZg4Q1o
#
# [1383 rows x 3 columns]

# %%
# !pip install youtube_transcript_api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: youtube_transcript_api in /usr/local/lib/python3.8/dist-packages (0.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from youtube_transcript_api) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->youtube_transcript_api) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->youtube_transcript_api) (2022.12.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->youtube_transcript_api) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->youtube_transcript_api) (2.10)

# %%
col_list =  list(df["id"])

print(col_list)
# Out:
# ['Bj6lC93JMi0', 'KjY94sAKLlw', '8Xg7E9shq0U', 'Z1N9JzNax2k', '7f50sQYjNRA', 'tujhGdn1EMI', 'T2pd3KRSoHI', '9VPq1JxMfkA', '#NAME?', '30LWjhZzg50', '9ReSHQihuZw', 'hmkF77F9TLw', 'Vw7KklJ8Lj8', 'nu_pCVPKzTk', 'EExSSotojVI', 'dS44jZyj5gU', 'XwzcrhhyDkc', 'F6P0hve2clE', '8mAITcNt710', 'UGBJHYpHPvA', '_uSrE-gIdFc', 'kTp5xUtcalw', 'Kbauf9IgsC4', 'V_xro1bcAuA', 'O1KeXo8lE8A', 'jH85McHenvw', 'WbMUHSL2xpY', '7BHs1BzA4fs', 'A74TOX803D0', 'i_LwzRVP7bg', 'fW_OS3LGB9Q', 'hDfkyF8U-pw', 'qpOZup_3P_A', 'f4idgaq2VqA', 'a_iQb1lnAEQ', 'FzlpwoeSrE0', 'XBTJDpT2XaI', '3qBXWUpoPHo', 'u6gSSpfsoOQ', 'OXGznpKZ_sA', 'pdy3nh1tn6I', 'I549C6SmUnk', 'zJSY8tbf_ys', 'jZx8PMQjobk', 'j-_s8f5K30I', 'R9apl6B_ZgI', 'NVvIpqmf_Xc', 'SR5GxoFhIAU', 'eWRfhZUzrAc', 'xO17P9LVkK0', 'PmDJIooZjBE', 'GFO_txvwK_c', 'hQBwCWtXkK0', 'J-cSy5MeMOA', 'OIc7urJC0zY', 'ChTGbmR2NeM', 'Reny0cTTv24', '_gWfFEuert8', '5fb2aPlgoys', 'vYEkEMfoi1c', 'V53AHWun17s', 'bC7o8P_Ste4', 'ccfpj4eD6YM', 'PXMJ6FS7llk', 'VtRLrQ3Ev-U', 'HFWQdGn5DaU', 'ylJz7N-dv1E', 'mYUyaKmvu6Y', 'zhJLVFR3pE8', 'cT_ZYrS3tKc', '0n809nd4Zu4', 'gyMwXuJrbJQ', '8vfQ6SWBZ-U', 'F3J3PZj0zi0', 'HvxmF0FUwrM', 'Rs_rAxEsAvI', 'xSUm6iMtREA', 'xkBheRZTkaw', '59IXY5IDrBA', 'jpno8FSqpc8', 'sHuuo9L3e5c', 'gfmRrPjnEw4', 'L8ypSXwyBds', 'bbkBuqC1rU4', 'OqbGRZx4xUc', 'hDzgO2FB_ms', 'iRaai1IBlB0', 'sWMAsRqcoWc', 'stQ1IZEB2xk', 'XcjqapXfrhk', 'fgdpvwEWJ9M', 'WzfDo2Wpxks', 'bmpI252DmiI', 'Cy9fAvsXGZA', 'l8HB14TBzs8', 'jFfo23yIWac', 'g1vy03ZY5mM', 'xV7S8BhIeBo', 'KTFFdZSDiTU', '8124kv-632k', 'GZQkwx10p-8', 'AplluksKvzI', 'RZ4p-saaQkc', 'kUMe1FH4CHE', 'hN4Q04ODOEw', 'Aj7HLsJenVg', 'zrs7u6bdbUw', 'kF0UBL1eHeQ', 'PGyhBwLyK2U', 'ec8vSKJuZTk', 'CqCDOosvZIk', 'VPvVD8t02U8', 'ROjZy1WbCIA', 'GHTA143_b-s', '8jLOx1hD3_o', 'QeRSEoqpKVI', 'KCgYDCKqato', 'UEngvxZ11sw', 'cQx6ig3mp1U', 'GwHX6FM-BHw', 'hEAg47jdYMs', 'lRaL-8qZ0mM', 'xl5fqr-CpTY', 'YD0egXpd-Y0', 'UiYhTcqx_wk', 'zHcef4eHOc8', 'iHF5fwsqu4I', 'cPOtULagNnI', 'FJDVKeh7RJI', 'VtLXKU1PpRU', 'T-H4nJQyMig', 'd6WC5n9G_sM', 'RiCQzBluTxU', 'gbyYXgiSgdM', 'mEPm9w5QlJM', 'Peq4GCPNC5c', 'bMknfKXIFA8', 'M3ZWfamWrBM', 'jwCmIBJ8Jtc', '025QFeZfeyM', 'b_IDdQzPRR4', 'erka8USiBgM', '47NRaBVxgVM', 'Hj_rA0dhr2I', 'F5KJVuii0Yw', 'OUzaUJ3gEug', 'VZ6LifcOXfM', '#NAME?', 'poLzjLt2yqU', 'eru2emiqow0', 'MsocPEZBd-M', 'xh4gy1lbL2k', 'WcDaZ67TVRo', '#NAME?', 'hZ1DASYd9rk', 'qsTthZi23VE', 'SOTamWNgDKc', 'EtEb40LE5zQ', 'Mo0Oco3Vimo', '4HoJIgyclZ4', 'lKKsjpH09dU', '4HSxX-EKJjw', 'xr6uZDRTna0', 'ZtqBQ68cfJc', '0sOvCWFmrtA', 'HS6KHYIYdXc', '1DklrGoAxDE', '0oSsLbh_Kv4', 'FjrKMcnKahY', 'SOjZTmOMGcY', 'AAu8bjj6-UI', 'OJnaBhCixng', 'fAAZixBzIAI', 'qwfE7fSVaZM', 'Ej_02ICOIgs', 'g2JOHLHh4rI', 'V4waklkBC38', 'cPmjQ9V6Hbk', 'Uszj_k0DGsg', '-8LTPIJBGwQ', 'dIUTsFT2MeQ', '9uFQECk30kA', 's8XjEuplx_U', 'o0XbHvKxw7Y', 'RaTpreA0v7Q', '1hvVcEhcbLM', 'M576WGiDBdQ', 'pkYVOmU3MgA', 'FXpIoQ_rT_c', 'D56hs0Twfco', 'j7VZsCCnptM', 'NWONeJKn6kc', 'UjDpW_SOrlw', 'bo_LP6QOUio', '__izua1kKeI', 'pyXnX2SEaFc', '_vCT42vDfgw', 'N2opj8XzYBY', 'tLKKmouUams', 'GJFHqK_-ARA', 'Mo4vesaut8g', 'UGRDM86MBIQ', '916GWv2Qs08', 'tWVWeAqZ0WU', 'ToXna81iij0', 'zN8YNNHcaZc', 'K2qjAixgLqk', '#NAME?', 'A80YzvNwqXA', 'tXIhdp5R7sc', 'skq7E2xS1Bo', 'ER8oKX5myE0', 'IJDJ0kBx2LM', 'OzUzrs8uJl8', '_C8kWso4ne4', 'e2IbNHi4uCI', 'ZpwZS3XnEZA', 'nTeuhbP7wdE', 'KsoUiNv1SZA', 'M1_v5HBVHWo', 'jBzwzrDvZ18', 'Jppuj6M1sJ4', 'LLKza5oULAA', 'RYDiDpW2VkM', 'r8UvWSX3KA8', 'ZXdFisA_hOY', 'ZYb_ZU8LNxs', 'jS4aFq5-91M', 'l7-f9gS8VOs', 'OwZHNH8EfSU', 'jcTj6FgWOpo', 'j5Zsa_eOXeY', 'P3qmqUZJ7l0', 'iJKCj8uAHz8', 'zJ-LqeX_fLU', 'P4Z8_qe2Cu0', 'Gaosub7FRf4', 'jBlTQjcKuaY', '1WmNXEVia8I', '01sAkU_NvOY', '4OaHB0JbJDI', 'aook54SsfhY', 'i_Iq4_Kd7Rc', 'LiOzTQAz13Q', 'l8Imtec4ReQ', 'agbh1wbfJt8', 'gTVpBbFWry8', 'iXNsAYOTzgM', '10PbGbTUSAg', '9zUHg7xjIqQ', 'mrHNSanmqQ4', '45MIykWJ-C4', '74NW-84BqbA', 'WnMQ8HlmeXc', 'mDgEqoQUBgk', '04L0BbAcCpQ', 'gB1F9G0JXOo', 'O79pJ7qXwoE', '8dfePlONtls', '0B5eIE_1vpU', 'Yg5zkd9nm6w', 'RJ2kwpzX8so', 'Oe421EPjeBE', '7WiJGTPuVeU', 'SqvVm3QiQVk', 'UoTxOVEecbI', '8hly31xKli0', 'F-sFp_AvHc8', ...

# %%
chunk = np.array_split(np.array(col_list), 80) 
chu = chunk[0]
chunk_list = chu.tolist()

# %%
chunk_list
# Out:
# ['Bj6lC93JMi0',
#  'KjY94sAKLlw',
#  '8Xg7E9shq0U',
#  'Z1N9JzNax2k',
#  '7f50sQYjNRA',
#  'tujhGdn1EMI',
#  'T2pd3KRSoHI',
#  '9VPq1JxMfkA',
#  '#NAME?',
#  '30LWjhZzg50',
#  '9ReSHQihuZw',
#  'hmkF77F9TLw',
#  'Vw7KklJ8Lj8',
#  'nu_pCVPKzTk',
#  'EExSSotojVI',
#  'dS44jZyj5gU',
#  'XwzcrhhyDkc',
#  'F6P0hve2clE']

# %%
transcription = {}
for i in chunk_list:
    from youtube_transcript_api import YouTubeTranscriptApi
    try:
      srt = YouTubeTranscriptApi.get_transcript(i)  
      transcription[i] = srt     
    except:
      continue

# %%
transcription
# Out:
# {'Bj6lC93JMi0': [{'text': 'in this course you will learn how to',
#    'start': 0.0,
#    'duration': 3.48},
#   {'text': 'improve your JavaScript skills by',
#    'start': 1.74,
#    'duration': 4.619},
#   {'text': 'building a card game Gavin long teaches',
#    'start': 3.48,
#    'duration': 5.579},
#   {'text': 'this course Gavin is a freeco camp team',
#    'start': 6.359,
#    'duration': 5.221},
#   {'text': 'member and popular instructor hi and',
#    'start': 9.059,
#    'duration': 4.861},
#   {'text': "welcome I'm Gavin long I've been a",
#    'start': 11.58,
#    'duration': 4.5},
#   {'text': 'professional software developer for many',
#    'start': 13.92,
#    'duration': 4.5},
#   {'text': "years and over the years I've written in",
#    'start': 16.08,
#    'duration': 3.72},
#   {'text': 'a variety of different programming',
#    'start': 18.42,
#    'duration': 3.24},
#   {'text': 'languages depending on the relevant',
#    'start': 19.8,
#    'duration': 3.0},
#   {'text': 'project', 'start': 21.66, 'duration': 3.119},
#   {'text': 'c-sharp is my main programming language',
#    'start': 22.8,
#    'duration': 3.78},
#   {'text': 'but in spite of what your main',
#    'start': 24.779,
#    'duration': 4.201},
#   {'text': 'programming language may be be a Java',
#    'start': 26.58,
#    'duration': 4.439},
#   {'text': 'python c-sharp Etc', 'start': 28.98, 'duration': 3.84},
#   {'text': 'there is always this one other',
#    'start': 31.019,
#    'duration': 4.141},
#   {'text': 'programming language that is almost a',
#    'start': 32.82,
#    'duration': 4.079},
#   {'text': 'mandatory programming language for every',
#    'start': 35.16,
#    'duration': 4.02},
#   {'text': 'developer to learn that programming',
#    'start': 36.899,
#    'duration': 5.041},
#   {'text': 'language is of course JavaScript so why',
#    'start': 39.18,
#    'duration': 4.92},
#   {'text': 'is it so essential to learn JavaScript',
#    'start': 41.94,
#    'duration': 5.22},
#   {'text': 'well JavaScript is a great language that',
#    'start': 44.1,
#    'duration': 5.1},
#   {'text': 'can run both on the client and server',
#    'start': 47.16,
#    'duration': 3.0},
#   {'text': 'side', 'start': 49.2, 'duration': 3.839},
#   {'text': 'but it is also along with HTML and CSS a',
#    'start': 50.16,
#    'duration': 6.18},
#   {'text': 'core technology on the world wide web',
#    'start': 53.039,
#    'duration': 6.781},
#   {'text': 'according to Wikipedia 98 of websites',
#    'start': 56.34,
#    'duration': 5.64},
#   {'text': "use JavaScript on the client's side for",
#    'start': 59.82,
#    'duration': 4.199},
#   {'text': 'web page Behavior', 'start': 61.98, 'duration': 4.38},
#   {'text': 'sure this may change moving forward due',
#    'start': 64.019,
#    'duration': 4.561},
#   {'text': 'to Technologies like webassembly',
#    'start': 66.36,
#    'duration': 4.079},
#   {'text': 'which enables developers to leverage',
#    'start': 68.58,
#    'duration': 4.2},
#   {'text': 'programming languages like for example C',
#    'start': 70.439,
#    'duration': 4.561},
#   {'text': 'sharp for client-side web Behavior',
#    'start': 72.78,
#    'duration': 3.9},
#   {'text': 'functionality', 'start': 75.0, 'duration': 3.9},
#   {'text': "but I think it's safe to say that for",
#    'start': 76.68,
#    'duration': 4.86},
#   {'text': 'the foreseeable future JavaScript is',
#    'start': 78.9,
#    'duration': 3.84},
#   {'text': 'still going to be the dominant',
#    'start': 81.54,
#    'duration': 3.719},
#   {'text': 'technology for this client-side where',
#    'start': 82.74,
#    'duration': 5.22},
#   {'text': 'Behavior functionality so in this video',
#    'start': 85.259,
#    'duration': 5.701},
#   {'text': "we'll exercise our JavaScript skills to",
#    'start': 87.96,
#    'duration': 5.94},
#   {'text': 'create a browser-based basic card game',
#    'start': 90.96,
#    'duration': 4.979},
#   {'text': "by going through this video you'll",
#    'start': 93.9,
#    'duration': 3.6},
#   {'text': 'hopefully learn a few things about',
#    'start': 95.939,
#    'duration': 4.801},
#   {'text': 'JavaScript HTML CSS and visual studio',
#    'start': 97.5,
#    'duration': 5.64},
#   {'text': "code although you'll only create a basic",
#    'start': 100.74,
#    'duration': 4.5},
#   {'text': 'card game you can use the concepts',
#    'start': 103.14,
#    'duration': 3.299},
#   {'text': "you'll learn to create more", 'start': 105.24, 'duration': 3.12},
#   {'text': 'sophisticated card games like for',
#    'start': 106.439,
#    'duration': 4.68},
#   {'text': 'example blackjack or poker so please',
#    'start': 108.36,
#    'duration': 4.619},
#   {'text': 'feel free to make the application your',
#    'start': 111.119,
#    'duration': 4.741},
#   {'text': 'own and use the code as the basis for',
#    'start': 112.979,
#    'duration': 5.341},
#   {'text': 'your own card games at the very least',
#    'start': 115.86,
#    'duration': 4.5},
#   {'text': 'this video provides you with a great',
#    'start': 118.32,
#    'duration': 4.439},
#   {'text': 'JavaScript exercise I hope you enjoyed',
#    'start': 120.36,
#    'duration': 4.14},
#   {'text': 'this video and learn a few things along',
#    'start': 122.759,
#    'duration': 2.82},
#   {'text': 'the way', 'start': 124.5, 'duration': 3.36},
#   {'text': 'so this tutorial demonstrates how to',
#    'start': 125.579,
#    'duration': 5.1},
#   {'text': 'build a basic card game using vanilla',
#    'start': 127.86,
#    'duration': 7.2},
#   {'text': 'JavaScript basic CSS and HTML code',
#    'start': 130.679,
#    'duration': 7.081},
#   {'text': 'this tutorial not only covers creating a',
#    'start': 135.06,
#    'duration': 5.1},
#   {'text': 'basic card game using JavaScript but',
#    'start': 137.76,
#    'duration': 5.28},
#   {'text': 'also covers how to create Dynamic user',
#    'start': 140.16,
#    'duration': 4.799},
#   {'text': 'interactive code using vanilla',
#    'start': 143.04,
#    'duration': 3.12},
#   {'text': 'JavaScript', 'start': 144.959, 'duration': 3.301},
#   {'text': "we'll cover creating some animation",
#    'start': 146.16,
#    'duration': 4.74},
#   {'text': 'effects responsive layout design using',
#    'start': 148.26,
#    'duration': 7.02},
#   {'text': 'CSS grid CSS flexbox and media queries',
#    'start': 150.9,
#    'duration': 6.6},
#   {'text': 'how to dynamically change the positions',
#    'start': 155.28,
#    'duration': 4.74},
#   {'text': 'of grid cells so as to randomize the',
#    'start': 157.5,
#    'duration': 4.98},
#   {'text': 'positions of the cards contained in a',
#    'start': 160.02,
#    'duration': 5.76},
#   {'text': 'CSS grid using JavaScript local storage',
#    'start': 162.48,
#    'duration': 5.399},
#   {'text': 'and much more', 'start': 165.78, 'duration': 4.319},
#   {'text': 'I would say that the code is accessible',
#    'start': 167.879,
#    'duration': 5.461},
#   {'text': "to Learners at most levels I've kept the",
#    'start': 170.099,
#    'duration': 4.981},
#   {'text': 'code quite simple', 'start': 173.34, 'duration': 4.56},
#   {'text': 'if however you get lost at any point the',
#    'start': 175.08,
#    'duration': 4.68},
#   {'text': 'code can be downloaded from GitHub',
#    'start': 177.9,
#    'duration': 3.72},
#   {'text': 'please see a link below in the', 'start': 179.76, 'duration': 3.9},
#   {'text': 'description to the relevant GitHub',
#    'start': 181.62,
#    'duration': 4.02},
#   {'text': 'repository', 'start': 183.66, 'duration': 4.26},
#   {'text': 'in this video we are going to develop a',
#    'start': 185.64,
#    'duration': 5.94},
#   {'text': 'basic card game using vanilla JavaScript',
#    'start': 187.92,
#    'duration': 6.48},
#   {'text': "I'll use vs code as my code editor even",
#    'start': 191.58,
#    'duration': 4.439},
#   {'text': "though I'll develop the game on my Mac",
#    'start': 194.4,
#    'duration': 4.199},
#   {'text': 'you of course can use vs code for',
#    'start': 196.019,
#    'duration': 4.981},
#   {'text': 'Windows or Linux and the coding',
#    'start': 198.599,
#    'duration': 6.201},
#   {'text': 'experience will be very much the same',
#    'start': 201.0,
#    'duration': 3.8},
#   {'text': 'vs code is of course free open source',
#    'start': 209.239,
#    'duration': 5.441},
#   {'text': "software I'll be using the Chrome",
#    'start': 212.519,
#    'duration': 4.561},
#   {'text': 'browser for testing purposes', 'start': 214.68, 'duration': 5.339},
#   {'text': "so the game that we'll develop is very",
#    'start': 217.08,
#    'duration': 7.079},
#   {'text': "basic I've called it hunt the ace",
#    'start': 220.019,
#    'duration': 5.961},
#   {'text': "here's a brief description of the game",
#    'start': 224.159,
#    'duration': 5.401},
#   {'text': 'so we have four different cards one of',
#    'start': 225.98,
#    'duration': 5.8},
#   {'text': 'which is the Ace of Spades', 'start': 229.56, 'duration': 4.62},
#   {'text': 'the user clicks the play game button to',
#    'start': 231.78,
#    'duration': 4.019},
#   {'text': 'start the game', 'start': 234.18, 'duration': 4.32},
#   {'text': 'the cards are flipped over so that the',
#    'start': 235.799,
#    'duration': 4.561},
#   {'text': 'user can no longer see the face of the',
#    'start': 238.5,
#    'duration': 4.5},
#   {'text': 'cards our game then randomizes the',
#    'start': 240.36,
#    'duration': 5.34},
#   {'text': 'positions of the cards so the cards are',
#    'start': 243.0,
#    'duration': 5.22},
#   {'text': 'in effect shuffled the cards are then',
#    'start': 245.7,
#    'duration': 5.16},
#   {'text': 'positioned at random locations in a grid',
#    'start': 248.22,
#    'duration': 5.879},
#   {'text': 'layout each location corresponds to a',
#    'start': 250.86,
#    'duration': 6.059},
#   {'text': 'random whole number between one and four',
#    'start': 254.099,
#    'duration': 5.341},
#   {'text': 'the user can then guess where the user',
#    'start': 256.919,
#    'duration': 5.1},
#   {'text': 'thinks the Ace of Spades is by clicking',
#    'start': 259.44,
#    'duration': 4.08},
#   {'text': 'on the relevant card', 'start': 262.019, 'duration': 3.661},
#   {'text': 'once the user has clicked The Chosen',
#    'start': 263.52,
#    'duration': 4.38},
#   {'text': 'card the card then flips over and of',
#    'start': 265.68,
#    'duration': 4.38},
#   {'text': 'course the user is made aware of whether',
#    'start': 267.9,
#    'duration': 3.78},
#   {'text': 'the user has guessed the correct',
#    'start': 270.06,
#    'duration': 4.139},
#   {'text': 'position of the Ace of Spades', 'start': 271.68, 'duration': 5.76},
#   {'text': 'each game consists of four rounds',
#    'start': 274.199,
#    'duration': 6.121},
#   {'text': 'in each round the user attempts to guess',
#    'start': 277.44,
#    'duration': 5.699},
#   {'text': 'the location of the Ace of Spades if the',
#    'start': 280.32,
#    'duration': 5.159},
#   {'text': 'user fails to guess the position of the',
#    'start': 283.139,
#    'duration': 4.681},
#   {'text': 'Ace of Spades the user will not be',
#    'start': 285.479,
#    'duration': 5.401},
#   {'text': 'awarded any points for that round if the',
#    'start': 287.82,
#    'duration': 4.74},
#   {'text': 'user however guesses the correct',
#    'start': 290.88,
#    'duration': 4.14},
#   {'text': 'location of the Ace of Spades the user',
#    'start': 292.56,
#    'duration': 4.32},
#   {'text': 'is awarded points based on the round',
#    'start': 295.02,
#    'duration': 3.0},
#   {'text': 'number', 'start': 296.88, 'duration': 4.02},
#   {'text': "so yes it's a simple game but I thought",
#    'start': 298.02,
#    'duration': 4.86},
#   {'text': 'this might be a good JavaScript coding',
#    'start': 300.9,
#    'duration': 5.04},
#   {'text': 'exercise this code is fairly simple and',
#    'start': 302.88,
#    'duration': 4.62},
#   {'text': 'therefore this tutorial should be',
#    'start': 305.94,
#    'duration': 3.6},
#   {'text': 'accessible to a wide audience interested',
#    'start': 307.5,
#    'duration': 3.54},
#   {'text': 'in programming', 'start': 309.54, 'duration': 3.3},
#   {'text': 'if you like this video please hit the',
#    'start': 311.04,
#    'duration': 4.02},
#   {'text': 'like button for Content like this and',
#    'start': 312.84,
#    'duration': 4.32},
#   {'text': 'much more please consider subscribing',
#    'start': 315.06,
#    'duration': 3.96},
#   {'text': "and please ring the bell so that you'll",
#    'start': 317.16,
#    'duration': 3.72},
#   {'text': 'be notified of future content please',
#    'start': 319.02,
#    'duration': 3.54},
#   {'text': "note that I've included links Below in",
#    'start': 320.88,
#    'duration': 2.819},
#   {'text': 'the description to additional', 'start': 322.56, 'duration': 3.18},
#   {'text': 'information for more detail on certain',
#    'start': 323.699,
#    'duration': 5.821},
#   {'text': 'Concepts discussed in this tutorial',
#    'start': 325.74,
#    'duration': 5.88},
#   {'text': "let's create the project", 'start': 329.52, 'duration': 3.84},
#   {'text': "so let's get started", 'start': 331.62, 'duration': 3.66},
#   {'text': 'so all we need to do is open an empty',
#    'start': 333.36,
#    'duration': 3.72},
#   {'text': 'folder from within Visual Studio code',
#    'start': 335.28,
#    'duration': 3.9},
#   {'text': 'this folder is of course where our',
#    'start': 337.08,
#    'duration': 4.86},
#   {'text': 'project files will reside', 'start': 339.18, 'duration': 5.459},
#   {'text': "so I've created a folder which I have",
#    'start': 341.94,
#    'duration': 5.64},
#   {'text': 'aptly named hunt the ace to house the',
#    'start': 344.639,
#    'duration': 6.78},
#   {'text': 'files for this project on my computer',
#    'start': 347.58,
#    'duration': 6.059},
#   {'text': "let's create three files within Visual",
#    'start': 351.419,
#    'duration': 5.0},
#   {'text': "Studio code let's create a file named",
#    'start': 353.639,
#    'duration': 8.241},
#   {'text': 'index.html of course for our HTML code',
#    'start': 356.419,
#    'duration': 5.461},
#   {'text': "let's create a file named index.js of",
#    'start': 367.32,
#    'duration': 6.74},
#   {'text': 'course for our JavaScript code',
#    'start': 370.62,
#    'duration': 3.44},
#   {'text': "let's create a file named style.css of",
#    'start': 378.0,
#    'duration': 5.46},
#   {'text': 'course for our layout and styling code',
#    'start': 381.66,
#    'duration': 4.92},
#   {'text': "our CSS code let's create a folder to",
#    'start': 383.46,
#    'duration': 5.88},
#   {'text': 'house the images that will be used to',
#    'start': 386.58,
#    'duration': 5.88},
#   {'text': 'represent our cards as well as a card',
#    'start': 389.34,
#    'duration': 6.0},
#   {'text': "that will be used for our game's image",
#    'start': 392.46,
#    'duration': 4.5},
#   {'text': 'logo', 'start': 395.34, 'duration': 3.24},
#   {'text': 'you can download the relevant images',
#    'start': 396.96,
#    'duration': 5.78},
#   {'text': 'from GitHub at this location', 'start': 398.58, 'duration': 4.16},
#   {'text': 'great', 'start': 417.18, 'duration': 4.2},
#   {'text': 'the live server extension', 'start': 418.8, 'duration': 6.06},
#   {'text': "let's start by coding basic HTML code",
#    'start': 421.38,
#    'duration': 6.0},
#   {'text': 'So within Visual Studio code you can',
#    'start': 424.86,
#    'duration': 5.339},
#   {'text': 'generate boilerplate HTML code for',
#    'start': 427.38,
#    'duration': 5.159},
#   {'text': 'example the doctype tag that indicates',
#    'start': 430.199,
#    'duration': 6.06},
#   {'text': 'that we are using HTML5 the HTML tag',
#    'start': 432.539,
#    'duration': 6.961},
#   {'text': 'head and body tags along with relevant',
#    'start': 436.259,
#    'duration': 6.06},
#   {'text': 'meta Tags by simply typing in the',
#    'start': 439.5,
#    'duration': 5.28},
#   {'text': 'exclamation mark character followed by',
#    'start': 442.319,
#    'duration': 5.1},
#   {'text': 'pressing the Tab Key like this',
#    'start': 444.78,
#    'duration': 5.639},
#   {'text': "so I'm going to use semantic HTML to",
#    'start': 447.419,
#    'duration': 5.701},
#   {'text': 'create a tag named header which will',
#    'start': 450.419,
#    'duration': 5.581},
#   {'text': 'house header related HTML code in our',
#    'start': 453.12,
#    'duration': 6.0},
#   {'text': 'layout by semantic HTML I mean the tag',
#    'start': 456.0,
#    'duration': 5.699},
#   {'text': 'name is descriptive as to the purpose of',
#    'start': 459.12,
#    'duration': 5.1},
#   {'text': 'the tag rather than for example simply',
#    'start': 461.699,
#    'duration': 5.881},
#   {'text': 'using a div tag semantic HTML elements',
#    'start': 464.22,
#    'duration': 5.759},
#   {'text': 'are those that clearly describe their',
#    'start': 467.58,
#    'duration': 4.86},
#   {'text': 'meaning in a human readable and machine',
#    'start': 469.979,
#    'duration': 4.5},
#   {'text': 'readable way', 'start': 472.44, 'duration': 4.44},
#   {'text': 'so we can type the tag name and then',
#    'start': 474.479,
#    'duration': 4.321},
#   {'text': 'press the tab key and the code for the',
#    'start': 476.88,
#    'duration': 4.56},
#   {'text': 'HTML element is generated for us by',
#    'start': 478.8,
#    'duration': 4.5},
#   {'text': 'Visual Studio code', 'start': 481.44, 'duration': 3.9},
#   {'text': "let's include a div element that",
#    'start': 483.3,
#    'duration': 4.92},
#   {'text': 'contains a CSS class named header Dash',
#    'start': 485.34,
#    'duration': 5.28},
#   {'text': 'title Dash container', 'start': 488.22, 'duration': 4.74},
#   {'text': 'so a quick way to generate the HTML code',
#    'start': 490.62,
#    'duration': 4.799},
#   {'text': 'for the relevant tag that includes a',
#    'start': 492.96,
#    'duration': 4.92},
#   {'text': 'specific class attribute within Visual',
#    'start': 495.419,
#    'duration': 5.881},
#   {'text': 'Studio code is to type the tag name so',
#    'start': 497.88,
#    'duration': 4.499},
#   {'text': 'div', 'start': 501.3, 'duration': 3.78},
#   {'text': 'then type in a DOT followed by the class',
#    'start': 502.379,
#    'duration': 4.861},
#   {'text': 'name you wish to include within the',
#    'start': 505.08,
#    'duration': 3.36},
#   {'text': 'element', 'start': 507.24, 'duration': 3.72},
#   {'text': 'then simply press the Tab Key and visual',
#    'start': 508.44,
#    'duration': 4.62},
#   {'text': 'studio code automatically generates the',
#    'start': 510.96,
#    'duration': 4.319},
#   {'text': 'desired HTML code', 'start': 513.06, 'duration': 4.56},
#   {'text': "let's include a H1 element for our",
#    'start': 515.279,
#    'duration': 4.62},
#   {'text': "game's header", 'start': 517.62, 'duration': 4.2},
#   {'text': 'so we want our header to reflect the',
#    'start': 519.899,
#    'duration': 3.241},
#   {'text': 'name of the game', 'start': 521.82, 'duration': 5.4},
#   {'text': 'we are creating so punt the ace',
#    'start': 523.14,
#    'duration': 6.54},
#   {'text': 'you may be familiar with a visual studio',
#    'start': 527.22,
#    'duration': 6.059},
#   {'text': 'code extension named live server if',
#    'start': 529.68,
#    'duration': 5.279},
#   {'text': "you're not familiar with this extension",
#    'start': 533.279,
#    'duration': 4.141},
#   {'text': 'it is very useful for monitoring the',
#    'start': 534.959,
#    'duration': 5.401},
#   {'text': 'effects of changes made to your code',
#    'start': 537.42,
#    'duration': 4.56},
#   {'text': 'in real time', 'start': 540.36, 'duration': 3.539},
#   {'text': 'you can install the live server',
#    'start': 541.98,
#    'duration': 4.5},
#   {'text': 'extension from this location',
#    'start': 543.899,
#    'duration': 5.161},
#   {'text': 'so once the live server extension has',
#    'start': 546.48,
#    'duration': 4.68},
#   {'text': 'been installed we can launch our',
#    'start': 549.06,
#    'duration': 3.839},
#   {'text': 'application through Visual Studio code',
#    'start': 551.16,
#    'duration': 5.9},
#   {'text': 'using live Server Like This', 'start': 552.899, 'duration': 4.161},
#   {'text': 'we can then tile our code Editor to the',
#    'start': 559.8,
#    'duration': 4.86},
#   {'text': 'left of our screens and our browser to',
#    'start': 562.2,
#    'duration': 4.86},
#   {'text': 'the right of our screens and in this way',
#    'start': 564.66,
#    'duration': 4.2},
#   {'text': 'we can easily monitor the effects of',
#    'start': 567.06,
#    'duration': 4.38},
#   {'text': 'changes to our code without the need to',
#    'start': 568.86,
#    'duration': 4.74},
#   {'text': 'refresh the browser window every time we',
#    'start': 571.44,
#    'duration': 3.959},
#   {'text': 'make a change to our code', 'start': 573.6, 'duration': 4.38},
#   {'text': "so for example let's change our header",
#    'start': 575.399,
#    'duration': 6.0},
#   {'text': 'text to hunt the Ace of Spades and once',
#    'start': 577.98,
#    'duration': 4.74},
#   {'text': 'we have saved our code we can',
#    'start': 581.399,
#    'duration': 3.601},
#   {'text': 'immediately see the effects of our code',
#    'start': 582.72,
#    'duration': 5.96},
#   {'text': 'change within the browser window',
#    'start': 585.0,
#    'duration': 3.68},
#   {'text': 'create cards statically with card 3D CSS',
#    'start': 592.08,
#    'duration': 5.879},
#   {'text': 'effects', 'start': 595.44, 'duration': 4.5},
#   {'text': 'so we are first going to create a card',
#    'start': 597.959,
#    'duration': 4.621},
#   {'text': "statically then later we'll dynamically",
#    'start': 599.94,
#    'duration': 4.5},
#   {'text': 'generate the cards through JavaScript',
#    'start': 602.58,
#    'duration': 2.939},
#   {'text': 'code', 'start': 604.44, 'duration': 3.3},
#   {'text': "we'll appropriately use the document",
#    'start': 605.519,
#    'duration': 5.401},
#   {'text': 'object model to build our cards and add',
#    'start': 607.74,
#    'duration': 6.24},
#   {'text': 'them to the Dom document object model',
#    'start': 610.92,
#    'duration': 5.46},
#   {'text': "let's first create the card statically",
#    'start': 613.98,
#    'duration': 5.28},
#   {'text': 'through basic HTML and CSS code',
#    'start': 616.38,
#    'duration': 5.16},
#   {'text': "let's create a div tag that contains a",
#    'start': 619.26,
#    'duration': 5.34},
#   {'text': 'class named card Dash container within',
#    'start': 621.54,
#    'duration': 5.28},
#   {'text': "this div tag let's create a child div",
#    'start': 624.6,
#    'duration': 5.58},
#   {'text': 'element that contains a class named card',
#    'start': 626.82,
#    'duration': 5.94},
#   {'text': "within the card div element let's create",
#    'start': 630.18,
#    'duration': 4.86},
#   {'text': 'a child div element that contains a',
#    'start': 632.76,
#    'duration': 4.92},
#   {'text': 'class named card Dash inner', 'start': 635.04, 'duration': 4.62},
#   {'text': 'within the card Dash in a div element',
#    'start': 637.68,
#    'duration': 4.92},
#   {'text': "let's create a child development that",
#    'start': 639.66,
#    'duration': 6.78},
#   {'text': 'contains a class named card Dash front',
#    'start': 642.6,
#    'duration': 6.54},
#   {'text': "let's also create a child development",
#    'start': 646.44,
#    'duration': 5.1},
#   {'text': 'that contains a class named card Dash',
#    'start': 649.14,
#    'duration': 4.58},
#   {'text': 'back', 'start': 651.54, 'duration': 2.18},
#   {'text': "let's add an image element as a child",
#    'start': 663.24,
#    'duration': 4.14},
#   {'text': 'element to the dev element that contains',
#    'start': 665.64,
#    'duration': 4.62},
#   {'text': 'the class named card Dash front',
#    'start': 667.38,
#    'duration': 5.16},
#   {'text': 'as you may have guessed this image will',
#    'start': 670.26,
#    'duration': 4.56},
#   {'text': 'represent the front of the card',
#    'start': 672.54,
#    'duration': 4.919},
#   {'text': "so let's assign the image elements",
#    'start': 674.82,
#    'duration': 5.22},
#   {'text': 'Source tag the path of the image that',
#    'start': 677.459,
#    'duration': 5.88},
#   {'text': 'depicts the Jack of Clubs', 'start': 680.04, 'duration': 5.82},
#   {'text': 'so each card will contain the same back',
#    'start': 683.339,
#    'duration': 3.601},
#   {'text': 'image', 'start': 685.86, 'duration': 3.18},
#   {'text': 'so we can ensure this by adding the',
#    'start': 686.94,
#    'duration': 3.839},
#   {'text': 'appropriate image element as a child',
#    'start': 689.04,
#    'duration': 4.56},
#   {'text': 'element to the div tag that contains the',
#    'start': 690.779,
#    'duration': 6.74},
#   {'text': 'card dashback class like this', 'start': 693.6, 'duration': 3.919},
#   {'text': 'so we have built our card statically',
#    'start': 706.079,
#    'duration': 4.741},
#   {'text': 'using HTML code', 'start': 708.12, 'duration': 4.68},
#   {'text': "as you can see there's not much to look",
#    'start': 710.82,
#    'duration': 3.48},
#   {'text': 'at at present', 'start': 712.8, 'duration': 4.68},
#   {'text': 'so the next step is to style the card',
#    'start': 714.3,
#    'duration': 6.12},
#   {'text': 'using CSS code so that we can create our',
#    'start': 717.48,
#    'duration': 5.82},
#   {'text': 'card to look three-dimensional and',
#    'start': 720.42,
#    'duration': 5.64},
#   {'text': 'create the desired flip effect', 'start': 723.3, 'duration': 5.46},
#   {'text': 'our CSS code will create the illusion',
#    'start': 726.06,
#    'duration': 5.1},
#   {'text': 'that the card is a three-dimensional',
#    'start': 728.76,
#    'duration': 4.019},
#   {'text': 'object', 'start': 731.16, 'duration': 4.619},
#   {'text': "let's first reference our style.css file",
#    'start': 732.779,
#    'duration': 6.781},
#   {'text': 'from within the index.html file',
#    'start': 735.779,
#    'duration': 5.641},
#   {'text': "I'm not going to go into too much detail",
#    'start': 739.56,
#    'duration': 4.2},
#   {'text': 'explaining the CSS code because this',
#    'start': 741.42,
#    'duration': 5.76},
#   {'text': 'tutorial is more about JavaScript',
#    'start': 743.76,
#    'duration': 5.4},
#   {'text': 'please follow along with the code so',
#    'start': 747.18,
#    'duration': 4.38},
#   {'text': 'that your CSS code is consistent with',
#    'start': 749.16,
#    'duration': 3.48},
#   {'text': 'mine', 'start': 751.56, 'duration': 3.6},
#   {'text': "let's create the styling for the cards",
#    'start': 752.64,
#    'duration': 4.199},
#   {'text': 'Dash container element', 'start': 755.16, 'duration': 4.2},
#   {'text': 'by card container element I am of course',
#    'start': 756.839,
#    'duration': 4.921},
#   {'text': 'referring to the element that contains a',
#    'start': 759.36,
#    'duration': 5.58},
#   {'text': 'reference to the card Dash container CSS',
#    'start': 761.76,
#    'duration': 5.48},
#   {'text': 'class', 'start': 764.94, 'duration': 2.3},
#   {'text': "let's create the styling for the card",
#    'start': 771.24,
#    'duration': 4.219},
#   {'text': 'element', 'start': 773.16, 'duration': 2.299},
#   {'text': "let's create CSS variables to store the",
#    'start': 782.339,
#    'duration': 7.101},
#   {'text': 'dimensions of our cards', 'start': 785.88, 'duration': 3.56},
#   {'text': 'so basically the car dash inner element',
#    'start': 891.66,
#    'duration': 4.799},
#   {'text': 'contains the child elements card Dash',
#    'start': 893.88,
#    'duration': 6.42},
#   {'text': 'back and card Dash front the CSS code we',
#    'start': 896.459,
#    'duration': 5.88},
#   {'text': 'are creating facilitates a flip effect',
#    'start': 900.3,
#    'duration': 4.56},
#   {'text': 'between the front of the card and the',
#    'start': 902.339,
#    'duration': 4.381},
#   {'text': 'back of the card', 'start': 904.86, 'duration': 4.44},
#   {'text': 'we can test the flip effect by',
#    'start': 906.72,
#    'duration': 5.04},
#   {'text': 'implementing CSS code so that when we',
#    'start': 909.3,
#    'duration': 4.02},
#   {'text': 'hover our Mouse pointers over the',
#    'start': 911.76,
#    'duration': 3.6},
#   {'text': 'relevant card that the flip effect',
#    'start': 913.32,
#    'duration': 3.3},
#   {'text': 'occurs', 'start': 915.36, 'duration': 3.9},
#   {'text': 'so we are writing code so that the inner',
#    'start': 916.62,
#    'duration': 6.06},
#   {'text': 'Dash card element rotates 180 degrees on',
#    'start': 919.26,
#    'duration': 5.879},
#   {'text': 'its y-axis when a mouse pointer is',
#    'start': 922.68,
#    'duration': 5.099},
#   {'text': 'hovered over the relevant card',
#    'start': 925.139,
#    'duration': 5.961},
#   {'text': 'and we can now test this', 'start': 927.779, 'duration': 3.321},
#   {'text': 'excellent', 'start': 931.32, 'duration': 2.72},
#   {'text': 'before we create our cards dynamically',
#    'start': 943.74,
#    'duration': 3.779},
#   {'text': 'through JavaScript code and', 'start': 945.72, 'duration': 3.96},
#   {'text': 'appropriately add the cards to the',
#    'start': 947.519,
#    'duration': 4.26},
#   {'text': "document object model let's create a",
#    'start': 949.68,
#    'duration': 5.519},
#   {'text': 'grid for the game area if you like where',
#    'start': 951.779,
#    'duration': 5.341},
#   {'text': 'the cards will be placed', 'start': 955.199, 'duration': 3.781},
#   {'text': "so firstly let's create four", 'start': 957.12, 'duration': 4.8},
#   {'text': 'placeholders denoting the positions of',
#    'start': 958.98,
#    'duration': 6.18},
#   {'text': 'each of the cards in the gameplay area',
#    'start': 961.92,
#    'duration': 7.38},
#   {'text': 'so card Dash pause Dash a card Dash',
#    'start': 965.16,
#    'duration': 8.7},
#   {'text': 'pause Dash B cards Dash pause Dash C and',
#    'start': 969.3,
#    'duration': 8.36},
#   {'text': 'card Dash pause Dash D', 'start': 973.86, 'duration': 3.8},
#   {'text': "so you can see here in the CSS code I've",
#    'start': 977.82,
#    'duration': 4.74},
#   {'text': 'given the body element a height of 100',
#    'start': 980.399,
#    'duration': 5.221},
#   {'text': 'VH this simply means the height of the',
#    'start': 982.56,
#    'duration': 5.219},
#   {'text': 'body of the HTML document', 'start': 985.62, 'duration': 4.5},
#   {'text': 'will take up a hundred percent of the',
#    'start': 987.779,
#    'duration': 4.261},
#   {'text': 'viewport height of the screen', 'start': 990.12, 'duration': 4.2},
#   {'text': 'so I want the gameplay area to be',
#    'start': 992.04,
#    'duration': 4.56},
#   {'text': 'aligned centrally within the main',
#    'start': 994.32,
#    'duration': 4.86},
#   {'text': 'element and take up an area based on the',
#    'start': 996.6,
#    'duration': 4.62},
#   {'text': 'width of the cards', 'start': 999.18, 'duration': 4.92},
#   {'text': "so let's write the code for this",
#    'start': 1001.22,
#    'duration': 5.4},
#   {'text': "so I'm using flexbox functionality for",
#    'start': 1004.1,
#    'duration': 4.799},
#   {'text': 'the display to centrally align the',
#    'start': 1006.62,
#    'duration': 4.74},
#   {'text': 'gameplay area I.E the area that will',
#    'start': 1008.899,
#    'duration': 4.86},
#   {'text': 'contain our cards', 'start': 1011.36, 'duration': 4.44},
#   {'text': "so I'm going to use the calc CSS",
#    'start': 1013.759,
#    'duration': 4.44},
#   {'text': 'function to calculate the width of the',
#    'start': 1015.8,
#    'duration': 3.779},
#   {'text': 'gameplay area', 'start': 1018.199, 'duration': 4.26},
#   {'text': 'two cards will reside side by side on',
#    'start': 1019.579,
#    'duration': 4.021},
#   {'text': 'each row', 'start': 1022.459, 'duration': 2.941},
#   {'text': 'the card Dash container style',
#    'start': 1023.6,
#    'duration': 6.199},
#   {'text': 'essentially denotes the gameplay area',
#    'start': 1025.4,
#    'duration': 4.399},
#   {'text': 'then to display the cards in a grid',
#    'start': 1070.52,
#    'duration': 5.58},
#   {'text': 'that will have two cards on each row we',
#    'start': 1073.16,
#    'duration': 4.98},
#   {'text': 'can use the grid functionality provided',
#    'start': 1076.1,
#    'duration': 3.9},
#   {'text': 'in CSS', 'start': 1078.14, 'duration': 4.02},
#   {'text': 'we can control where each individual',
#    'start': 1080.0,
#    'duration': 5.039},
#   {'text': 'card will reside by allocating each card',
#    'start': 1082.16,
#    'duration': 6.0},
#   {'text': 'position element a position in the grid',
#    'start': 1085.039,
#    'duration': 5.52},
#   {'text': 'by using the grid Dash template Dash',
#    'start': 1088.16,
#    'duration': 6.139},
#   {'text': 'areas property like this', 'start': 1090.559, 'duration': 3.74},
#   {'text': 'so to get a clear picture of our layout',
#    'start': 1126.08,
#    'duration': 5.64},
#   {'text': "let's add border styles to the relevant",
#    'start': 1129.2,
#    'duration': 5.66},
#   {'text': 'HTML elements', 'start': 1131.72, 'duration': 3.14},
#   {'text': 'great', 'start': 1158.96, 'duration': 4.26},
#   {'text': "let's give each of the grid cells",
#    'start': 1161.179,
#    'duration': 4.981},
#   {'text': 'different background colors so that we',
#    'start': 1163.22,
#    'duration': 4.62},
#   {'text': 'can get a clear picture of the layout of',
#    'start': 1166.16,
#    'duration': 2.94},
#   {'text': 'the grid', 'start': 1167.84, 'duration': 3.78},
#   {'text': 'note that each of the four cards used in',
#    'start': 1169.1,
#    'duration': 4.74},
#   {'text': 'this game will be placed in a specific',
#    'start': 1171.62,
#    'duration': 5.299},
#   {'text': 'cell within the grid', 'start': 1173.84, 'duration': 3.079},
#   {'text': 'great and we can see the grid cells',
#    'start': 1186.98,
#    'duration': 3.66},
#   {'text': 'clearly', 'start': 1189.679, 'duration': 3.0},
#   {'text': 'so we have now created the grid within',
#    'start': 1190.64,
#    'duration': 5.0},
#   {'text': 'the gameplay area', 'start': 1192.679, 'duration': 2.961},
#   {'text': 'create cards dynamically through',
#    'start': 1197.72,
#    'duration': 3.959},
#   {'text': 'JavaScript', 'start': 1199.88, 'duration': 3.9},
#   {'text': 'we have created our cards statically',
#    'start': 1201.679,
#    'duration': 5.281},
#   {'text': "through HTML and CSS let's create the",
#    'start': 1203.78,
#    'duration': 5.88},
#   {'text': "cards dynamically using JavaScript let's",
#    'start': 1206.96,
#    'duration': 5.94},
#   {'text': "go to our index.js file let's create an",
#    'start': 1209.66,
#    'duration': 5.46},
#   {'text': 'array of objects each object within the',
#    'start': 1212.9,
#    'duration': 4.44},
#   {'text': 'array denotes a card or a card',
#    'start': 1215.12,
#    'duration': 5.64},
#   {'text': 'definition each object has an ID',
#    'start': 1217.34,
#    'duration': 6.719},
#   {'text': 'property and an image Path property the',
#    'start': 1220.76,
#    'duration': 5.279},
#   {'text': 'first item is the king of hearts and has',
#    'start': 1224.059,
#    'duration': 4.74},
#   {'text': 'an ID of one the second item is a jack',
#    'start': 1226.039,
#    'duration': 5.461},
#   {'text': 'of clubs and has an ID of two the third',
#    'start': 1228.799,
#    'duration': 5.701},
#   {'text': 'item is the Queen of Diamonds and has an',
#    'start': 1231.5,
#    'duration': 5.6},
#   {'text': 'idea of three', 'start': 1234.5, 'duration': 2.6},
#   {'text': 'the fourth item is the Ace of Spades and',
#    'start': 1239.419,
#    'duration': 6.081},
#   {'text': 'has an ID of four', 'start': 1242.299, 'duration': 3.201},
#   {'text': "let's create a function named create",
#    'start': 1246.679,
#    'duration': 3.901},
#   {'text': 'card of course this function is',
#    'start': 1248.6,
#    'duration': 3.78},
#   {'text': 'responsible for creating a card',
#    'start': 1250.58,
#    'duration': 6.32},
#   {'text': 'dynamically through JavaScript code',
#    'start': 1252.38,
#    'duration': 4.52},
#   {'text': "firstly let's create a reusable function",
#    'start': 1260.48,
#    'duration': 5.16},
#   {'text': 'responsible for creating a HTML element',
#    'start': 1262.7,
#    'duration': 7.64},
#   {'text': "let's name this function create element",
#    'start': 1265.64,
#    'duration': 4.7},
#   {'text': 'we can create a HTML element and code',
#    'start': 1270.679,
#    'duration': 6.0},
#   {'text': 'through this line of code', 'start': 1273.559, 'duration': 5.761},
#   {'text': "let's use our create element method to",
#    'start': 1276.679,
#    'duration': 6.481},
#   {'text': 'create the div tags that make up a card',
#    'start': 1279.32,
#    'duration': 6.62},
#   {'text': 'so here we can see the static HTML code',
#    'start': 1283.16,
#    'duration': 5.7},
#   {'text': 'that we created earlier to represent a',
#    'start': 1285.94,
#    'duration': 5.099},
#   {'text': 'card', 'start': 1288.86, 'duration': 2.179},
#   {'text': 'so that we can see what we are creating',
#    'start': 1291.38,
#    'duration': 4.62},
#   {'text': 'here in code dynamically', 'start': 1293.24, 'duration': 5.46},
#   {'text': 'so basically we have a card element',
#    'start': 1296.0,
#    'duration': 4.799},
#   {'text': 'an inner card element within the card',
#    'start': 1298.7,
#    'duration': 5.28},
#   {'text': 'element a front and back element within',
#    'start': 1300.799,
#    'duration': 6.141},
#   {'text': 'the inner card element', 'start': 1303.98, 'duration': 2.96},
#   {'text': 'we can use the create element method to',
#    'start': 1328.159,
#    'duration': 4.621},
#   {'text': 'create our image elements', 'start': 1330.919, 'duration': 4.321},
#   {'text': 'that contain the back card image and the',
#    'start': 1332.78,
#    'duration': 5.3},
#   {'text': 'front card image', 'start': 1335.24, 'duration': 2.84},
#   {'text': "let's create a reusable method that adds",
#    'start': 1352.7,
#    'duration': 6.44},
#   {'text': 'a class to a HTML element', 'start': 1355.7, 'duration': 3.44},
#   {'text': "let's write code to add the card class",
#    'start': 1370.159,
#    'duration': 5.481},
#   {'text': 'to the card element', 'start': 1372.679, 'duration': 2.961},
#   {'text': "let's write a method that adds an ID",
#    'start': 1380.96,
#    'duration': 7.02},
#   {'text': 'to a HTML element so each card will be',
#    'start': 1384.32,
#    'duration': 7.14},
#   {'text': 'assigned a unique ID the ID will come',
#    'start': 1387.98,
#    'duration': 5.04},
#   {'text': 'from the array of card object',
#    'start': 1391.46,
#    'duration': 4.26},
#   {'text': 'definitions that we created earlier',
#    'start': 1393.02,
#    'duration': 5.399},
#   {'text': "I'll create card method accepts one",
#    'start': 1395.72,
#    'duration': 5.1},
#   {'text': 'argument this argument will be an item',
#    'start': 1398.419,
#    'duration': 6.681},
#   {'text': 'from the card object definitions array',
#    'start': 1400.82,
#    'duration': 4.28},
#   {'text': "let's write code to add the inner card",
#    'start': 1422.36,
#    'duration': 6.38},
#   {'text': 'class to the inner card element',
#    'start': 1424.76,
#    'duration': 3.98},
#   {'text': "let's write code to add the appropriate",
#    'start': 1440.539,
#    'duration': 6.0},
#   {'text': 'class to the front dash card element',
#    'start': 1442.76,
#    'duration': 7.159},
#   {'text': 'and the back card element', 'start': 1446.539, 'duration': 3.38},
#   {'text': "let's write a reusable method that",
#    'start': 1475.82,
#    'duration': 5.28},
#   {'text': 'assigns a path for the relevant image to',
#    'start': 1478.159,
#    'duration': 7.76},
#   {'text': 'the SRC attribute of an image element',
#    'start': 1481.1,
#    'duration': 4.819},
#   {'text': 'okay before we assign the image path',
#    'start': 1503.059,
#    'duration': 5.1},
#   {'text': 'properties for the card', 'start': 1505.6, 'duration': 5.14},
#   {'text': 'to the appropriate image elements',
#    'start': 1508.159,
#    'duration': 5.161},
#   {'text': "let's create a const to store the path",
#    'start': 1510.74,
#    'duration': 5.34},
#   {'text': 'for the image that represents the back',
#    'start': 1513.32,
#    'duration': 5.42},
#   {'text': 'of a card', 'start': 1516.08, 'duration': 2.66},
#   {'text': "right let's assign the image paths",
#    'start': 1528.32,
#    'duration': 4.7},
#   {'text': 'appropriately', 'start': 1530.419, 'duration': 2.601},
#   {'text': "let's write code to assign the card Dash",
#    'start': 1540.86,
#    'duration': 7.04},
#   {'text': 'image class to the image elements',
#    'start': 1543.5,
#    'duration': 4.4},
#   {'text': 'so now that we have our basic elements',
#    'start': 1596.96,
#    'duration': 4.079},
#   {'text': "created in code let's assign the child",
#    'start': 1598.88,
#    'duration': 4.02},
#   {'text': 'elements appropriately to their parent',
#    'start': 1601.039,
#    'duration': 4.14},
#   {'text': "elements so let's create a reusable",
#    'start': 1602.9,
#    'duration': 5.399},
#   {'text': 'method named ADD child element',
#    'start': 1605.179,
#    'duration': 5.461},
#   {'text': 'the code within this method simply adds',
#    'start': 1608.299,
#    'duration': 4.321},
#   {'text': 'the child element passed in as an',
#    'start': 1610.64,
#    'duration': 4.139},
#   {'text': 'argument to the second parameter to the',
#    'start': 1612.62,
#    'duration': 4.2},
#   {'text': 'parent element passed in as an argument',
#    'start': 1614.779,
#    'duration': 5.361},
#   {'text': 'to the first parameter', 'start': 1616.82, 'duration': 3.32},
#   {'text': "so let's write code to add the image",
#    'start': 1621.32,
#    'duration': 4.5},
#   {'text': 'elements to their appropriate parent',
#    'start': 1623.659,
#    'duration': 4.821},
#   {'text': 'elements', 'start': 1625.82, 'duration': 2.66},
#   {'text': "let's write codes to add the front dash",
#    'start': 1647.059,
#    'duration': 4.62},
#   {'text': 'card element and the back dash card',
#    'start': 1649.52,
#    'duration': 6.32},
#   {'text': 'element to the inner Dash card element',
#    'start': 1651.679,
#    'duration': 4.161},
#   {'text': "let's write code to add the inner Dash",
#    'start': 1676.58,
#    'duration': 6.199},
#   {'text': 'card element to the card element',
#    'start': 1679.1,
#    'duration': 3.679},
#   {'text': "let's create a global const and store a",
#    'start': 1689.539,
#    'duration': 4.74},
#   {'text': 'reference to the card Dash container',
#    'start': 1692.539,
#    'duration': 2.64},
#   {'text': 'element', 'start': 1694.279, 'duration': 2.701},
#   {'text': 'we are not going to add the card',
#    'start': 1695.179,
#    'duration': 4.261},
#   {'text': 'elements directly to this element but we',
#    'start': 1696.98,
#    'duration': 4.26},
#   {'text': 'will use this element constant a bit',
#    'start': 1699.44,
#    'duration': 2.82},
#   {'text': 'later', 'start': 1701.24, 'duration': 2.88},
#   {'text': 'when we write code to alter the',
#    'start': 1702.26,
#    'duration': 4.62},
#   {'text': 'positions of the grid cells each grid',
#    'start': 1704.12,
#    'duration': 5.52},
#   {'text': 'cell will contain one of our cards the',
#    'start': 1706.88,
#    'duration': 4.32},
#   {'text': 'cells of the grid', 'start': 1709.64, 'duration': 4.26},
#   {'text': 'are child elements of the card container',
#    'start': 1711.2,
#    'duration': 4.26},
#   {'text': 'element', 'start': 1713.9, 'duration': 4.62},
#   {'text': 'we are using the CSS grid system for the',
#    'start': 1715.46,
#    'duration': 5.459},
#   {'text': 'grid functionality which represents the',
#    'start': 1718.52,
#    'duration': 4.92},
#   {'text': 'gameplay area I.E where our cards will',
#    'start': 1720.919,
#    'duration': 5.181},
#   {'text': 'be displayed', 'start': 1723.44, 'duration': 2.66},
#   {'text': "let's write code to appropriately add",
#    'start': 1727.82,
#    'duration': 5.04},
#   {'text': 'each card element as a child element to',
#    'start': 1729.86,
#    'duration': 4.919},
#   {'text': 'their appropriate grid cell', 'start': 1732.86, 'duration': 4.38},
#   {'text': 'each grid cell is denoted by a div',
#    'start': 1734.779,
#    'duration': 4.76},
#   {'text': 'element', 'start': 1737.24, 'duration': 2.299},
#   {'text': 'we are going to map each card to its',
#    'start': 1739.82,
#    'duration': 4.68},
#   {'text': 'initial position by mapping the card',
#    'start': 1742.58,
#    'duration': 4.8},
#   {'text': "element's ID to the appropriate element",
#    'start': 1744.5,
#    'duration': 5.82},
#   {'text': 'that represents a grid cell', 'start': 1747.38, 'duration': 5.279},
#   {'text': 'this is how our code will know as it',
#    'start': 1750.32,
#    'duration': 4.8},
#   {'text': 'were which card must be assigned to',
#    'start': 1752.659,
#    'duration': 6.921},
#   {'text': 'which positional parent div element',
#    'start': 1755.12,
#    'duration': 4.46},
#   {'text': "so let's create a method named add card",
#    'start': 1766.94,
#    'duration': 4.68},
#   {'text': 'to grid cell', 'start': 1769.64, 'duration': 4.68},
#   {'text': "let's create a method named Map Card ID",
#    'start': 1771.62,
#    'duration': 4.32},
#   {'text': 'to grid cell', 'start': 1774.32, 'duration': 3.719},
#   {'text': 'this method will be called within the',
#    'start': 1775.94,
#    'duration': 5.219},
#   {'text': 'add card to grid cell method so if the',
#    'start': 1778.039,
#    'duration': 6.061},
#   {'text': 'card ID is one we want this card to be',
#    'start': 1781.159,
#    'duration': 5.161},
#   {'text': 'added as a child element to the first',
#    'start': 1784.1,
#    'duration': 4.679},
#   {'text': 'position in the grid which is denoted by',
#    'start': 1786.32,
#    'duration': 5.099},
#   {'text': 'a div element with the cart Dash pause',
#    'start': 1788.779,
#    'duration': 5.701},
#   {'text': 'Dash a CSS class', 'start': 1791.419, 'duration': 6.301},
#   {'text': 'if card ID is 2 we want this card to be',
#    'start': 1794.48,
#    'duration': 5.88},
#   {'text': 'added as a child element to the second',
#    'start': 1797.72,
#    'duration': 5.04},
#   {'text': 'position in the grid which is denoted by',
#    'start': 1800.36,
#    'duration': 4.919},
#   {'text': 'a div element with the card Dash pause',
#    'start': 1802.76,
#    'duration': 5.58},
#   {'text': 'Dash B CSS class', 'start': 1805.279, 'duration': 6.301},
#   {'text': 'if card ID is three we want this card to',
#    'start': 1808.34,
#    'duration': 5.339},
#   {'text': 'be added as a child element to the third',
#    'start': 1811.58,
#    'duration': 4.86},
#   {'text': 'position in the grid which is denoted by',
#    'start': 1813.679,
#    'duration': 5.701},
#   {'text': 'a div element with the card Dash pause',
#    'start': 1816.44,
#    'duration': 5.52},
#   {'text': 'Dash C CSS class', 'start': 1819.38, 'duration': 6.299},
#   {'text': 'if card ID is four we want this card to',
#    'start': 1821.96,
#    'duration': 5.819},
#   {'text': 'be added as a child element to the',
#    'start': 1825.679,
#    'duration': 3.901},
#   {'text': 'fourth position in the grid which is',
#    'start': 1827.779,
#    'duration': 4.441},
#   {'text': 'denoted by a div element with the card',
#    'start': 1829.58,
#    'duration': 6.66},
#   {'text': 'Dash pause Dash D CSS class then within',
#    'start': 1832.22,
#    'duration': 6.66},
#   {'text': "the add card to grid cell method let's",
#    'start': 1836.24,
#    'duration': 4.62},
#   {'text': 'write the code that finds the', 'start': 1838.88, 'duration': 4.5},
#   {'text': 'appropriate parent element for the child',
#    'start': 1840.86,
#    'duration': 3.78},
#   {'text': 'card element', 'start': 1843.38, 'duration': 4.38},
#   {'text': 'using the map grid ID to grid cell',
#    'start': 1844.64,
#    'duration': 6.12},
#   {'text': 'method and then adds the childcard',
#    'start': 1847.76,
#    'duration': 7.639},
#   {'text': 'element to its designated parent element',
#    'start': 1850.76,
#    'duration': 4.639},
#   {'text': "then within the create card method let's",
#    'start': 1861.2,
#    'duration': 5.099},
#   {'text': 'write code to appropriately call the add',
#    'start': 1863.779,
#    'duration': 6.38},
#   {'text': 'card to grid cell method', 'start': 1866.299, 'duration': 3.86},
#   {'text': "so let's write a method that will Loop",
#    'start': 1878.659,
#    'duration': 4.02},
#   {'text': 'through each of the objects stored',
#    'start': 1881.0,
#    'duration': 4.62},
#   {'text': 'within the card object definitions array',
#    'start': 1882.679,
#    'duration': 5.1},
#   {'text': 'create the relevant cards and add the',
#    'start': 1885.62,
#    'duration': 4.02},
#   {'text': 'cards to their appropriate grid',
#    'start': 1887.779,
#    'duration': 4.62},
#   {'text': "positions so let's create a method named",
#    'start': 1889.64,
#    'duration': 4.919},
#   {'text': 'create cards', 'start': 1892.399, 'duration': 4.14},
#   {'text': 'then all we need to do is write code',
#    'start': 1894.559,
#    'duration': 4.321},
#   {'text': 'that calls the create card method within',
#    'start': 1896.539,
#    'duration': 4.26},
#   {'text': 'the for each Loop that Loops through',
#    'start': 1898.88,
#    'duration': 4.98},
#   {'text': 'each card definition to create the cards',
#    'start': 1900.799,
#    'duration': 6.301},
#   {'text': 'dynamically and add the cards to their',
#    'start': 1903.86,
#    'duration': 7.28},
#   {'text': 'appropriate position within the grid',
# ...
#    'start': 2052.24,
#    'duration': 4.679},
#   {'text': 'line even mean JavaScript runtime built',
#    'start': 2054.7,
#    'duration': 5.28},
#   {'text': "on Chrome's V8 JavaScript engine well we",
#    'start': 2056.919,
#    'duration': 5.041},
#   {'text': 'all know what a runtime is you can',
#    'start': 2059.98,
#    'duration': 3.72},
#   {'text': 'consider node.js kind of like a',
#    'start': 2061.96,
#    'duration': 4.08},
#   {'text': 'framework a backend framework', 'start': 2063.7, 'duration': 4.5},
#   {'text': 'for example flutter is a front-end',
#    'start': 2066.04,
#    'duration': 5.819},
#   {'text': 'framework node.js is a backend framework',
#    'start': 2068.2,
#    'duration': 6.659},
#   {'text': "and Chrome's V8 JavaScript engine this",
#    'start': 2071.859,
#    'duration': 5.641},
#   {'text': 'line right here basically Chrome runs on',
#    'start': 2074.859,
#    'duration': 4.621},
#   {'text': 'this JavaScript engine which is called',
#    'start': 2077.5,
#    'duration': 5.46},
#   {'text': 'V8 and this V8 JavaScript engine is',
#    'start': 2079.48,
#    'duration': 5.699},
#   {'text': "written in C plus plus which means it's",
#    'start': 2082.96,
#    'duration': 5.399},
#   {'text': 'terribly fast by terribly fast I mean',
#    'start': 2085.179,
#    'duration': 6.66},
#   {'text': "it's pretty fast not in a bad way but it",
#    'start': 2088.359,
#    'duration': 6.721},
#   {'text': 'just means simply that Chrome V8 allows',
#    'start': 2091.839,
#    'duration': 6.481},
#   {'text': "us to execute JavaScript code and that's",
#    'start': 2095.08,
#    'duration': 6.36},
#   {'text': 'exactly what node.js is using Chrome is',
#    'start': 2098.32,
#    'duration': 5.82},
#   {'text': "built on Chrome's V8 engine even node.js",
#    'start': 2101.44,
#    'duration': 4.74},
#   {'text': "is built on Chrome's V8 engine and thus",
#    'start': 2104.14,
#    'duration': 4.8},
#   {'text': 'allows us to write code over there so',
#    'start': 2106.18,
#    'duration': 5.52},
#   {'text': 'this is pretty much all about node.js I',
#    'start': 2108.94,
#    'duration': 4.98},
#   {'text': 'think you got a very brief idea about it',
#    'start': 2111.7,
#    'duration': 4.8},
#   {'text': 'so now if you want to install it if',
#    'start': 2113.92,
#    'duration': 3.9},
#   {'text': "you're on Windows this will show you",
#    'start': 2116.5,
#    'duration': 3.3},
#   {'text': 'windows and just click on this version',
#    'start': 2117.82,
#    'duration': 4.259},
#   {'text': 'or this version this version is',
#    'start': 2119.8,
#    'duration': 5.52},
#   {'text': "recommended for most users but I'm using",
#    'start': 2122.079,
#    'duration': 5.76},
#   {'text': '18 version and if you want to verify',
#    'start': 2125.32,
#    'duration': 4.08},
#   {'text': "that you've installed successfully just",
#    'start': 2127.839,
#    'duration': 5.101},
#   {'text': 'go to your terminal and write node dash',
#    'start': 2129.4,
#    'duration': 7.08},
#   {'text': 'dash version and it says version 18.1.0',
#    'start': 2132.94,
#    'duration': 5.04},
#   {'text': "but I don't think it will make a",
#    'start': 2136.48,
#    'duration': 3.18},
#   {'text': 'difference even if you use a lower',
#    'start': 2137.98,
#    'duration': 5.04},
#   {'text': 'version like 16.17 even 14 works just',
#    'start': 2139.66,
#    'duration': 6.72},
#   {'text': "well for me as so now let's get done",
#    'start': 2143.02,
#    'duration': 6.18},
#   {'text': "with all of this now we'll come to our",
#    'start': 2146.38,
#    'duration': 6.12},
#   {'text': "root file let's close all the save files",
#    'start': 2149.2,
#    'duration': 7.02},
#   {'text': 'clear of a terminal and in the root we',
#    'start': 2152.5,
#    'duration': 6.24},
#   {'text': "need to create a folder so I'm going to",
#    'start': 2156.22,
#    'duration': 6.18},
#   {'text': 'type make directory which is mkdir which',
#    'start': 2158.74,
#    'duration': 5.52},
#   {'text': 'will make a folder and we need to name',
#    'start': 2162.4,
#    'duration': 4.56},
#   {'text': 'This Server so now we have a server',
#    'start': 2164.26,
#    'duration': 4.38},
#   {'text': 'folder ready instead you could just',
#    'start': 2166.96,
#    'duration': 3.78},
#   {'text': 'click over here and create a folder same',
#    'start': 2168.64,
#    'duration': 4.08},
#   {'text': 'thing but it should be in the root of',
#    'start': 2170.74,
#    'duration': 3.24},
#   {'text': 'your uh', 'start': 2172.72, 'duration': 4.8},
#   {'text': 'folder of docs clone', 'start': 2173.98, 'duration': 5.7},
#   {'text': "now let's go to the server so I'm going",
#    'start': 2177.52,
#    'duration': 4.38},
#   {'text': 'to use CD which means change directory',
#    'start': 2179.68,
#    'duration': 3.24},
#   {'text': 'server', 'start': 2181.9, 'duration': 5.06},
#   {'text': "and now I'm going to run npm init this",
#    'start': 2182.92,
#    'duration': 7.74},
#   {'text': 'npm is node package manager node package',
#    'start': 2186.96,
#    'duration': 6.22},
#   {'text': 'manager is like pub.dev so if you just',
#    'start': 2190.66,
#    'duration': 5.28},
#   {'text': 'go to their website', 'start': 2193.18, 'duration': 5.82},
#   {'text': 'which is npmgs.com', 'start': 2195.94, 'duration': 7.02},
#   {'text': 'you can see this npm right here this is',
#    'start': 2199.0,
#    'duration': 5.7},
#   {'text': "not the real name don't get confused by",
#    'start': 2202.96,
#    'duration': 4.26},
#   {'text': "it it's just for fun if you just click",
#    'start': 2204.7,
#    'duration': 4.02},
#   {'text': 'over here you can see it keeps on',
#    'start': 2207.22,
#    'duration': 2.879},
#   {'text': 'changing', 'start': 2208.72, 'duration': 4.2},
#   {'text': 'anyways so here you can search for',
#    'start': 2210.099,
#    'duration': 4.921},
#   {'text': 'packages just like flutter we can have',
#    'start': 2212.92,
#    'duration': 4.679},
#   {'text': 'multiple packages for example if in',
#    'start': 2215.02,
#    'duration': 5.16},
#   {'text': 'flutter View using HTTP package you can',
#    'start': 2217.599,
#    'duration': 4.5},
#   {'text': 'have the same thing here as well which',
#    'start': 2220.18,
#    'duration': 5.22},
#   {'text': 'is HTTP the same thing I mean this one',
#    'start': 2222.099,
#    'duration': 6.421},
#   {'text': 'is same but there are multiple that are',
#    'start': 2225.4,
#    'duration': 5.64},
#   {'text': 'different as well for example if you',
#    'start': 2228.52,
#    'duration': 5.28},
#   {'text': 'want to use something like Express that',
#    'start': 2231.04,
#    'duration': 4.319},
#   {'text': 'was mentioned over here you can see',
#    'start': 2233.8,
#    'duration': 3.96},
#   {'text': "we're going to use this as well so",
#    'start': 2235.359,
#    'duration': 4.5},
#   {'text': 'basically this will manage all the',
#    'start': 2237.76,
#    'duration': 5.099},
#   {'text': 'packages and npm', 'start': 2239.859, 'duration': 6.0},
#   {'text': 'will allow us to initialize our node',
#    'start': 2242.859,
#    'duration': 5.76},
#   {'text': 'project so here we are just writing npm',
#    'start': 2245.859,
#    'duration': 5.401},
#   {'text': 'init and then if we click on enter just',
#    'start': 2248.619,
#    'duration': 5.101},
#   {'text': "try to do it yourself you'll see that",
#    'start': 2251.26,
#    'duration': 4.079},
#   {'text': "you'll get a bunch of options you just",
#    'start': 2253.72,
#    'duration': 3.54},
#   {'text': 'have to click enter on them but a',
#    'start': 2255.339,
#    'duration': 4.441},
#   {'text': 'shortcut to avoid that is just typing',
#    'start': 2257.26,
#    'duration': 5.88},
#   {'text': "Dash Y which means that you'll",
#    'start': 2259.78,
#    'duration': 5.819},
#   {'text': 'initialize it and all the options that',
#    'start': 2263.14,
#    'duration': 4.74},
#   {'text': 'are asked later on will be defaulted to',
#    'start': 2265.599,
#    'duration': 4.201},
#   {'text': "yes that's exactly what we wanted so",
#    'start': 2267.88,
#    'duration': 5.219},
#   {'text': "I've done that npm init Dash file",
#    'start': 2269.8,
#    'duration': 5.52},
#   {'text': "now in the server folder I'm going to",
#    'start': 2273.099,
#    'duration': 5.161},
#   {'text': 'create a new file called index.js in',
#    'start': 2275.32,
#    'duration': 6.0},
#   {'text': 'this index.js before coming over here we',
#    'start': 2278.26,
#    'duration': 5.579},
#   {'text': 'need to go to the package.json now what',
#    'start': 2281.32,
#    'duration': 5.759},
#   {'text': 'exactly is package.json package.json can',
#    'start': 2283.839,
#    'duration': 6.0},
#   {'text': 'be considered like pubspec.yaml file it',
#    'start': 2287.079,
#    'duration': 5.581},
#   {'text': 'contains a name version description the',
#    'start': 2289.839,
#    'duration': 5.341},
#   {'text': 'main file which means the file that we',
#    'start': 2292.66,
#    'duration': 4.5},
#   {'text': 'want to run in the start', 'start': 2295.18, 'duration': 4.98},
#   {'text': 'the scripts well multiple scripts that',
#    'start': 2297.16,
#    'duration': 5.34},
#   {'text': "we'll have we'll get into this in just a",
#    'start': 2300.16,
#    'duration': 5.06},
#   {'text': 'minute then you have author license',
#    'start': 2302.5,
#    'duration': 6.119},
#   {'text': 'every everything that you need',
#    'start': 2305.22,
#    'duration': 7.06},
#   {'text': 'to create a flutter package',
#    'start': 2308.619,
#    'duration': 7.621},
#   {'text': "and your node package it's just the same",
#    'start': 2312.28,
#    'duration': 6.48},
#   {'text': 'thing as pubspect.tml file it will',
#    'start': 2316.24,
#    'duration': 4.56},
#   {'text': 'manage all our dependencies it will',
#    'start': 2318.76,
#    'duration': 4.38},
#   {'text': 'manage all our Dev dependencies',
#    'start': 2320.8,
#    'duration': 5.1},
#   {'text': 'similar everything is pretty similar',
#    'start': 2323.14,
#    'duration': 4.86},
#   {'text': 'so now in the scripts I want to change',
#    'start': 2325.9,
#    'duration': 4.14},
#   {'text': 'something so we are going to add two',
#    'start': 2328.0,
#    'duration': 4.68},
#   {'text': 'scripts well first of all is the start',
#    'start': 2330.04,
#    'duration': 6.02},
#   {'text': 'one which means which is short for',
#    'start': 2332.68,
#    'duration': 8.04},
#   {'text': 'node dot slash index.js now what does',
#    'start': 2336.06,
#    'duration': 6.82},
#   {'text': "this mean wait a second I'll show it to",
#    'start': 2340.72,
#    'duration': 5.52},
#   {'text': 'you for example here I type console.log',
#    'start': 2342.88,
#    'duration': 5.84},
#   {'text': "hello world if you're wondering what",
#    'start': 2346.24,
#    'duration': 5.4},
#   {'text': "console.log is it's basically print in",
#    'start': 2348.72,
#    'duration': 4.0},
#   {'text': 'Dot', 'start': 2351.64, 'duration': 2.699},
#   {'text': 'it will just print it out to the',
#    'start': 2352.72,
#    'duration': 3.48},
#   {'text': 'terminal and', 'start': 2354.339, 'duration': 4.26},
#   {'text': "if you're on web it will print it out on",
#    'start': 2356.2,
#    'duration': 3.36},
#   {'text': 'the web', 'start': 2358.599, 'duration': 5.161},
#   {'text': "here if I just type let's say node dot",
#    'start': 2359.56,
#    'duration': 5.42},
#   {'text': 'slash', 'start': 2363.76, 'duration': 3.96},
#   {'text': "index.js because I'm in the server",
#    'start': 2364.98,
#    'duration': 5.379},
#   {'text': 'folder I can use dot slash if I was in',
#    'start': 2367.72,
#    'duration': 4.859},
#   {'text': 'the root folder I would have to use dot',
#    'start': 2370.359,
#    'duration': 4.921},
#   {'text': "slash server slash index.js it's",
#    'start': 2372.579,
#    'duration': 4.26},
#   {'text': 'relative routing', 'start': 2375.28, 'duration': 3.839},
#   {'text': 'now if I just click on enter you can see',
#    'start': 2376.839,
#    'duration': 4.141},
#   {'text': 'Hello World prints out', 'start': 2379.119, 'duration': 3.781},
#   {'text': "what I've done here is instead of",
#    'start': 2380.98,
#    'duration': 3.96},
#   {'text': 'writing this command this entire big',
#    'start': 2382.9,
#    'duration': 4.92},
#   {'text': 'command what I can do is just use npm',
#    'start': 2384.94,
#    'duration': 4.32},
#   {'text': 'start', 'start': 2387.82, 'duration': 3.66},
#   {'text': 'and it does the same thing it will run',
#    'start': 2389.26,
#    'duration': 5.099},
#   {'text': 'this command when uh behind the scenes',
#    'start': 2391.48,
#    'duration': 7.139},
#   {'text': 'and print the same thing out to us',
#    'start': 2394.359,
#    'duration': 7.26},
#   {'text': 'why is this needed well', 'start': 2398.619, 'duration': 5.881},
#   {'text': 'if you deploy deploy it online you will',
#    'start': 2401.619,
#    'duration': 4.921},
#   {'text': 'have to use something like npm start so',
#    'start': 2404.5,
#    'duration': 3.66},
#   {'text': "that it starts a server you can't use",
#    'start': 2406.54,
#    'duration': 4.98},
#   {'text': "nodes dot slash index.js and now let's",
#    'start': 2408.16,
#    'duration': 5.34},
#   {'text': 'try to install some dependencies to',
#    'start': 2411.52,
#    'duration': 4.319},
#   {'text': 'install our dependencies what do we use',
#    'start': 2413.5,
#    'duration': 4.74},
#   {'text': 'to do well we would use this dot add',
#    'start': 2415.839,
#    'duration': 4.76},
#   {'text': 'dependency otherwise we would go to',
#    'start': 2418.24,
#    'duration': 5.4},
#   {'text': 'pubspect.aml file and over here manually',
#    'start': 2420.599,
#    'duration': 5.321},
#   {'text': 'add them but', 'start': 2423.64, 'duration': 5.64},
#   {'text': 'another the third option would be to use',
#    'start': 2425.92,
#    'duration': 8.34},
#   {'text': 'something like flutter Pub add and then',
#    'start': 2429.28,
#    'duration': 7.74},
#   {'text': "the name of the dependency right that's",
#    'start': 2434.26,
#    'duration': 5.099},
#   {'text': "exactly what we're going to do over here",
#    'start': 2437.02,
#    'duration': 5.099},
#   {'text': 'here we are going to write npm',
#    'start': 2439.359,
#    'duration': 5.941},
#   {'text': 'I or install both of them work even',
#    'start': 2442.119,
#    'duration': 6.24},
#   {'text': 'iWorks even install Works other name',
#    'start': 2445.3,
#    'duration': 5.16},
#   {'text': 'suggests it will install dependencies',
#    'start': 2448.359,
#    'duration': 4.141},
#   {'text': 'whatever we type here so what all',
#    'start': 2450.46,
#    'duration': 4.619},
#   {'text': 'dependencies do we need well I said we',
#    'start': 2452.5,
#    'duration': 4.74},
#   {'text': "need Express right we'll install that",
#    'start': 2455.079,
#    'duration': 4.921},
#   {'text': "I'll tell you what Express means when we",
#    'start': 2457.24,
#    'duration': 6.839},
#   {'text': "get it then we need HTTP I said we're",
#    'start': 2460.0,
#    'duration': 5.64},
#   {'text': "going to need that you'll understand",
#    'start': 2464.079,
#    'duration': 3.241},
#   {'text': 'when we write the code', 'start': 2465.64, 'duration': 7.32},
#   {'text': 'then we need socket dot IO at 2.3.0 this',
#    'start': 2467.32,
#    'duration': 7.1},
#   {'text': 'is very important', 'start': 2472.96, 'duration': 5.36},
#   {'text': 'socket.io at 2.3.0 why do we need at',
#    'start': 2474.42,
#    'duration': 8.32},
#   {'text': '2.3.0 well because the sockets are',
#    'start': 2478.32,
#    'duration': 6.94},
#   {'text': 'managed in such way that it needs to be',
#    'start': 2482.74,
#    'duration': 4.56},
#   {'text': 'connected on the client side as well and',
#    'start': 2485.26,
#    'duration': 4.56},
#   {'text': 'in the server side as well so when we',
#    'start': 2487.3,
#    'duration': 3.96},
#   {'text': 'are connecting it on the client side',
#    'start': 2489.82,
#    'duration': 3.18},
#   {'text': "we're going to use another package",
#    'start': 2491.26,
#    'duration': 3.42},
#   {'text': "because we can't manually write the",
#    'start': 2493.0,
#    'duration': 4.5},
#   {'text': "whole socket client code it's very big",
#    'start': 2494.68,
#    'duration': 5.159},
#   {'text': "and it's very tough to understand as",
#    'start': 2497.5,
#    'duration': 4.38},
#   {'text': 'well so we already have a package for it',
#    'start': 2499.839,
#    'duration': 3.721},
#   ...]}

# %%
type(transcription)
# Out:
# dict

# %%
# Serializing json
json_object = json.dumps(transcription, indent=2)
# Writing to sample.json
with open("sample.json", "w") as outfile:
   outfile.write(json_object)
